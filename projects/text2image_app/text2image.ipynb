# %%
import requests
from PIL import Image
from io import BytesIO
from PIL import Image as PILImage
from IPython.display import Image
'''
# URL of the image
url = "https://example.com/image.jpg"

# Get the image data from the URL
response = requests.get(url)
img_data = response.content

# Create a PIL image object from the image data
img = Image.open(BytesIO(img_data))

# Display the image
img.show()
'''
# Out:
# '\n# URL of the image\nurl = "https://example.com/image.jpg"\n\n# Get the image data from the URL\nresponse = requests.get(url)\nimg_data = response.content\n\n# Create a PIL image object from the image data\nimg = Image.open(BytesIO(img_data))\n\n# Display the image\nimg.show()\n'

# %% [markdown]
# ## Search

# %%
url = "https://engine.prod.bria-api.com/v1/search"

headers = {
    "api_token": ""
}

query = {
  "query": "grey marble with golden veins",
  "synchronous": "false",
  "gallery_search": "false",
  "num_results_per_page": "1",
  "synthetic_search": "true",
  "num_synthetic_results_per_page": "4",
  "page": "1",
  "style": "oil painting",
  "atmosphere": "vivid",
  #"camera": "portrait",
  "medium": "art"
}

response = requests.get(url, headers=headers, params=query)

data = response.json()
print(data)
# Out:
# {'results': [{'synthetic_url': 'https://bria-temp.s3.amazonaws.com/api/generate_image/an_illustration_of_a_grey_marble_with_golden_veins_paint_strokes_dripping_paint_oil_painting_concept_art_oil_illustration_splattered_oil_Vivid_colors/seed_1600596135.jpg?AWSAccessKeyId=ASIAUL5JH7ABE57VJON2&Signature=Ry66KoI%2FKG9cU3LhESK12j1iECI%3D&x-amz-security-token=FwoGZXIvYXdzEGwaDO4xHZJfsRubZXftTCKYBCuW8RYfqpF5pcOOr22IzrZxvSH%2F9fLPcDe7j26TyJMEursGZXdwPnKskz3VbCAIoGXfHHwkkmwdmXpYqUuPEKSpRoUL9zraNicEbqQGAzedXVY9rCW5i%2BhGSxguW9jz8sFBEvtZsydd%2BeCFpESJvNi%2FZ8O6z3JS6cNnZyg%2FIQOGV4S2VuzvvKBqbOv0llbEKvDmVRroIgBPrSVK9R635yW%2FaFp5aKIenc0QvCDbrm5wXC5FpttYQGXR0O3cKPgNz8sQTVLmLkD9LZtPzAmBUfyq21%2FUuWYJbKLoKatCRgKNr3ZCG824DTNpVsSrJed%2FfYqJeDQUmZYE1A5z2j8tUD72Ubu0jHuJCi47Ybvx3ipJbCa%2BhJpTxv2fznm31cyLhig1x2GqhYZNN%2FjljNevQFzIbV%2FwlPfiDcSNN1tQC4TY1%2F1TAIZtxCzE74UefIzJqPCR2yejjn%2BCb%2BvGWmtTEsn%2FLm74ng9zoFsQg3wm1%2FBZhVZ5HS9BBjqeTYJyw%2Ftk2URUWEMmKcLtufmYZ3%2Bm1hkgqJ3gs9%2F%2FE31IUHwkyJWykpm4%2FSr5SjJpdLAswhLsi1Nied95w%2Beefbjst18DKyqrI05Kg3i5kLQqmirTqKsdRd72k%2BtC82hS9nWk7bzDzv%2Bl%2BDzUB1B9YkzPkfnosnuc25NtXmIKFbqY5dmraC29ZssU5dHrVeaPFBoeRGwCtzKxVVO2v2S7KKDr3p8GMirhaH5bV1GJbX52m5%2FtiKipViHExTHo%2F3WQYZmS%2B7FAJfmg%2FnUlabaJwg0%3D&Expires=1678042527', 'type': 'url', 'url': 'https://bria-temp.s3.amazonaws.com/api/generate_image/an_illustration_of_a_grey_marble_with_golden_veins_paint_strokes_dripping_paint_oil_painting_concept_art_oil_illustration_
FLm74ng9zoFsQg3wm1%2FBZhVZ5HS9BBjqeTYJyw%2Ftk2URUWEMmKcLtufmYZ3%2Bm1hkgqJ3gs9%2F%2FE31IUHwkyJWykpm4%2FSr5SjJpdLAswhLsi1Nied95w%2Beefbjst18DKyqrI05Kg3i5kLQqmirTqKsdRd72k%2BtC82hS9nWk7bzDzv%2Bl%2BDzUB1B9YkzPkfnosnuc25NtXmIKFbqY5dmraC29ZssU5dHrVeaPFBoeRGwCtzKxVVO2v2S7KKDr3p8GMirhaH5bV1GJbX52m5%2FtiKipViHExTHo%2F3WQYZmS%2B7FAJfmg%2FnUlabaJwg0%3D&Expires=1678042527', 'type': 'url', 'url': 'https://bria-temp.s3.amazonaws.com/api/generate_image/an_illustration_of_a_grey_marble_with_golden_veins_paint_strokes_dripping_paint_oil_painting_concept_art_oil_illustration_splattered_oil_Vivid_colors/seed_ ...

# %%
url = data['results'][0]['synthetic_url']
print(url)

# Get the image data from the URL
response = requests.get(url)
#img_data = Image(response.content)

Image(response.content)
# Create a PIL image object from the image data
#img = PILImage.open(BytesIO(img_data))

# Display the image
#img.show()
# Out:
# https://bria-temp.s3.amazonaws.com/api/generate_image/an_illustration_of_a_grey_marble_with_golden_veins_paint_strokes_dripping_paint_oil_painting_concept_art_oil_illustration_splattered_oil_Vivid_colors/seed_1600596135.jpg?AWSAccessKeyId=ASIAUL5JH7ABE57VJON2&Signature=Ry66KoI%2FKG9cU3LhESK12j1iECI%3D&x-amz-security-token=FwoGZXIvYXdzEGwaDO4xHZJfsRubZXftTCKYBCuW8RYfqpF5pcOOr22IzrZxvSH%2F9fLPcDe7j26TyJMEursGZXdwPnKskz3VbCAIoGXfHHwkkmwdmXpYqUuPEKSpRoUL9zraNicEbqQGAzedXVY9rCW5i%2BhGSxguW9jz8sFBEvtZsydd%2BeCFpESJvNi%2FZ8O6z3JS6cNnZyg%2FIQOGV4S2VuzvvKBqbOv0llbEKvDmVRroIgBPrSVK9R635yW%2FaFp5aKIenc0QvCDbrm5wXC5FpttYQGXR0O3cKPgNz8sQTVLmLkD9LZtPzAmBUfyq21%2FUuWYJbKLoKatCRgKNr3ZCG824DTNpVsSrJed%2FfYqJeDQUmZYE1A5z2j8tUD72Ubu0jHuJCi47Ybvx3ipJbCa%2BhJpTxv2fznm31cyLhig1x2GqhYZNN%2FjljNevQFzIbV%2FwlPfiDcSNN1tQC4TY1%2F1TAIZtxCzE74UefIzJqPCR2yejjn%2BCb%2BvGWmtTEsn%2FLm74ng9zoFsQg3wm1%2FBZhVZ5HS9BBjqeTYJyw%2Ftk2URUWEMmKcLtufmYZ3%2Bm1hkgqJ3gs9%2F%2FE31IUHwkyJWykpm4%2FSr5SjJpdLAswhLsi1Nied95w%2Beefbjst18DKyqrI05Kg3i5kLQqmirTqKsdRd72k%2BtC82hS9nWk7bzDzv%2Bl%2BDzUB1B9YkzPkfnosnuc25NtXmIKFbqY5dmraC29ZssU5dHrVeaPFBoeRGwCtzKxVVO2v2S7KKDr3p8GMirhaH5bV1GJbX52m5%2FtiKipViHExTHo%2F3WQYZmS%2B7FAJfmg%2FnUlabaJwg0%3D&Expires=1678042527

# %%
url = data['results'][3]['url']
print(url)

# Get the image data from the URL
response = requests.get(url)
#img_data = response.content
Image(response.content)
# Create a PIL image object from the image data
#img = PILImage.open(BytesIO(img_data))

# Display the image
#img.show()
# Out:
# https://bria-temp.s3.amazonaws.com/api/generate_image/an_illustration_of_a_grey_marble_with_golden_veins_paint_strokes_dripping_paint_oil_painting_concept_art_oil_illustration_splattered_oil_Vivid_colors/seed_1600596138.jpg?AWSAccessKeyId=ASIAUL5JH7ABE57VJON2&Signature=cIycBj4AXPIrqyx9ETfwfWE5NwM%3D&x-amz-security-token=FwoGZXIvYXdzEGwaDO4xHZJfsRubZXftTCKYBCuW8RYfqpF5pcOOr22IzrZxvSH%2F9fLPcDe7j26TyJMEursGZXdwPnKskz3VbCAIoGXfHHwkkmwdmXpYqUuPEKSpRoUL9zraNicEbqQGAzedXVY9rCW5i%2BhGSxguW9jz8sFBEvtZsydd%2BeCFpESJvNi%2FZ8O6z3JS6cNnZyg%2FIQOGV4S2VuzvvKBqbOv0llbEKvDmVRroIgBPrSVK9R635yW%2FaFp5aKIenc0QvCDbrm5wXC5FpttYQGXR0O3cKPgNz8sQTVLmLkD9LZtPzAmBUfyq21%2FUuWYJbKLoKatCRgKNr3ZCG824DTNpVsSrJed%2FfYqJeDQUmZYE1A5z2j8tUD72Ubu0jHuJCi47Ybvx3ipJbCa%2BhJpTxv2fznm31cyLhig1x2GqhYZNN%2FjljNevQFzIbV%2FwlPfiDcSNN1tQC4TY1%2F1TAIZtxCzE74UefIzJqPCR2yejjn%2BCb%2BvGWmtTEsn%2FLm74ng9zoFsQg3wm1%2FBZhVZ5HS9BBjqeTYJyw%2Ftk2URUWEMmKcLtufmYZ3%2Bm1hkgqJ3gs9%2F%2FE31IUHwkyJWykpm4%2FSr5SjJpdLAswhLsi1Nied95w%2Beefbjst18DKyqrI05Kg3i5kLQqmirTqKsdRd72k%2BtC82hS9nWk7bzDzv%2Bl%2BDzUB1B9YkzPkfnosnuc25NtXmIKFbqY5dmraC29ZssU5dHrVeaPFBoeRGwCtzKxVVO2v2S7KKDr3p8GMirhaH5bV1GJbX52m5%2FtiKipViHExTHo%2F3WQYZmS%2B7FAJfmg%2FnUlabaJwg0%3D&Expires=1678042528

# %% [markdown]
# ## Create (Not work)

# %%
visual_id = "8487fb411f3c6716"
url = "https://engine.prod.bria-api.com/v1/" + visual_id + "/create"

#url = "https://engine.prod.bria-api.com/v1/create"


payload = {
  "changes": [
    {
      "id": "a48284e4832c809e4475ad5de7bdd333658e363b417a28991022a6fa79488a6b",
      "actions": {
        "age": "mid-60",
        "diversity": "france",
        "expression": "happy",
        "glasses": "light",
        "haircolor": "brown",
        "gender": "masculinity",
        "makeup": "none",
        "hair_line": "high",
        "beard": "medium"
      }
    }
  ]
}
'''

payload = {
  "changes": [
    {
      "id": "a48284e4832c809e4475ad5de7bdd333658e363b417a28991022a6fa79488a6b",
      "actions": {
        "description": "grey marble with golden veins"
      }
    }
  ]
}
''' 

headers = {
    "api_token": ""
}
''' 
query = {
  "query": "grey marble with golden veins",
  "synchronous": "true",
  "gallery_search": "false",
  "num_results_per_page": "1",
  "synthetic_search": "true",
  "num_synthetic_results_per_page": "1",
  "page": "1",
  "style": "realistic",
  "atmosphere": "vivid",
  "camera": "portrait",
  "medium": "art"
}'''

response = requests.post(url, json=payload, headers=headers, params=query)
#response = requests.post(url, headers=headers, params=query)

data = response.json()
print(data)
# Out:
# {'code': 500, 'name': 'Internal Server Error', 'description': 'The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.'}

# %%
import io
import time
import requests
from typing import Dict, List, Optional


api_url: str = "https://engine.prod.bria-api.com/v1/"
auth_headers: Dict[str, str] = {
    "api_token": ""
}
source_image_url: str = "https://pixabay.com/get/g2f990f4fe7c60fc32517d61aa120b84edcccb0d4ae2154b90dd240d6e66190aa7e9aacbd4d0b7e8288f7dd0c21fac39b32c7c787be0eb03194aaf807362e226a7ff489fab80c3b9b76d651173e7e85a1_640.jpg"

    
def upload() -> str:
    res = requests.get(source_image_url, timeout=20.0)
    if res.status_code != requests.codes.ok:
        raise Exception()
    input_image = io.BytesIO(res.content)
    response = requests.request(
        method="POST",
        url=f"{api_url}/upload",
        headers=auth_headers,
        data={},
        files=[
            (
                "file",
                (
                    "8928f232dc8bdb35.jpeg",
                    input_image,
                    "image/jpeg",
                ),
            )
        ],
    )
    res: Dict = response.json()
    code: int = res.get("code")
    visual_id: Optional[str] = None  # used this for all other reuqest
    if code == 200:  # image uploaded for the first time
        visual_id = res.get("visual_id")
    elif code == 603:  # in case the image alrady uploaded
        visual_id = res.get("response_body").get("visual_id")
    if visual_id is None:
        exit(0)
    return visual_id


def info(visual_id: str) -> Dict:
    response = requests.request(
        method="GET",
        url=f"{api_url}/{visual_id}/info",
        headers=auth_headers,
    )
    return response.json()


def create(info: Dict, visual_id: str) -> Dict:
    print(info)
    scene_object: Dict = info["scene"][0]
    scene_object_id: str = scene_object.get("id")
    actions: Dict = scene_object.get("actions")

    # The api support the folowiing.
    # Note that any of these can be returned null, if that is the case we dont support a action for this image
    age_action: Optional[Dict] = actions.get("age")
    diversity_actions: Optional[List[str]] = actions.get("diversity")
    glasses_actions: Optional[List[str]] = actions.get("glasses")
    expressions_actions: Optional[List[str]] = actions.get("expressions")
    hair_color_actions: Optional[List[str]] = actions.get("hair_color")
    gender_actions: Optional[List[str]] = actions.get("gender")
    makeup_actions: Optional[List[str]] = actions.get("makeup")
    hair_line_actions: Optional[List[str]] = actions.get("hair_line")

    response = requests.request(
        method="POST",
        url=f"{api_url}/{visual_id}/create",
        headers=auth_headers,
        json={
            "changes": [
                {
                    "id": scene_object_id,
                    "actions": {"diversity": diversity_actions[0]},
                }
            ],
        },
    )

    return response.json()


past = time.time()
visual_id: str = upload()
print(visual_id)
image_info: Dict = info(visual_id=visual_id)
new_created_image: Dict = create(info=image_info, visual_id=visual_id)
time_diff: int = time.time() - past

image_url: str = new_created_image.get("image_res")
confidence: str = new_created_image.get("confidence")

print(
    f"New image created with after {time_diff}-sec with confidence: {confidence}, get it from {image_url}"
)
# Out:
# None
# {'code': 404, 'name': 'Not Found', 'description': 'Specified Image does not exist'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 94
#      92 print(visual_id)
#      93 image_info: Dict = info(visual_id=visual_id)
# ---> 94 new_created_image: Dict = create(info=image_info, visual_id=visual_id)
#      95 time_diff: int = time.time() - past
#      97 image_url: str = new_created_image.get("image_res")
#
# Cell In[1], line 58, in create(info, visual_id)
#      56 def create(info: Dict, visual_id: str) -> Dict:
#      57     print(info)
# ---> 58     scene_object: Dict = info["scene"][0]
#      59     scene_object_id: str = scene_object.get("id")
#      60     actions: Dict = scene_object.get("actions")
#
# KeyError: 'scene'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
